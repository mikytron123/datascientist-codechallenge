# %%
#importing libraries
import pandas as pd
import plotly.graph_objects as go
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import TimeSeriesSplit
import holidays
import joblib
import json
from sklearn.utils.discovery import all_estimators
from scipy.stats import randint,uniform

# %% [markdown]
# ### Data Preprocessing

# %%
#reading in
df = pd.read_csv("Sample Dataset.csv")

# Feature Engineering
holiday = holidays.country_holidays("CA", subdiv="ON")
df["Date"] = pd.to_datetime(df["Date"])
df["DateTime"] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Hour'].astype(str), format='%Y-%m-%d %H')
df = df.drop_duplicates(subset=["DateTime"])
df["Holiday"] = (df["DateTime"].apply(lambda x: x in (holiday))).astype(int)
df["Weekday_num"] = (df["DateTime"]).dt.dayofweek
df["Month_num"] = (df["DateTime"]).dt.month
df["Day"] = df["DateTime"].dt.day
df = df.set_index(["DateTime"])
# Out:
#                           Date Weekday  Hour  HOEP  Ontario_Demand  \
# DateTime
# 2016-01-01 00:00:00 2016-01-01  Friday     0  0.49           14023
# 2016-01-01 01:00:00 2016-01-01  Friday     1 -1.09           13417
# 2016-01-01 02:00:00 2016-01-01  Friday     2 -2.41           12968
# 2016-01-01 12:00:00 2016-01-01  Friday    12  0.00           14215
# 2016-01-01 13:00:00 2016-01-01  Friday    13  0.00           14443
#
#                      Temperature  Windchill_Index  Wind_Speed  Humidex  \
# DateTime
# 2016-01-01 00:00:00         -0.3            -5.62          20    -3.18
# 2016-01-01 01:00:00         -0.3            -6.30          25    -3.48
# 2016-01-01 02:00:00         -0.4            -6.55          26    -3.43
# 2016-01-01 12:00:00         -2.1            -8.72          23    -4.86
# 2016-01-01 13:00:00         -2.4            -8.23          19    -5.09
#
#                      Relative_Humidity  Dew_Point  Pressure_Station  Holiday  \
# DateTime
# 2016-01-01 00:00:00                 70       -5.1             99.67        1
# 2016-01-01 01:00:00                 68       -5.5             99.63        1
# 2016-01-01 02:00:00                 73       -4.7             99.59        1
# 2016-01-01 12:00:00                 76       -5.8             99.39        1
# 2016-01-01 13:00:00                 84       -4.7             99.35        1
#
#                      Weekday_num  Month_num  Day
# DateTime
# 2016-01-01 00:00:00            4          1    1
# 2016-01-01 01:00:00            4          1    1
# 2016-01-01 02:00:00            4          1    1
# 2016-01-01 12:00:00            4          1    1
# 2016-01-01 13:00:00            4          1    1

# %% [markdown]
# ### Visualization

# %%
#visualizing histogram
for col in df.select_dtypes("number").columns:
    x=df[col]
    fig = go.Figure(data=[go.Histogram(x=x)])
    fig.update_layout(title=col)
    fig.show()

# %%
#visualizing time series
for col in df.select_dtypes("number").columns:
    x=df.index
    y=df[col]
    fig = go.Figure(data=go.Scatter(x=x, y=y))
    fig.update_layout(title=col)
    fig.show()

# %% [markdown]
# ### Removing outliers

# %%
outliers = {"Temperature":{"min":-20},
            "Windchill_Index":{"min":-30},
            "Wind_Speed":{"max":50},
            "Humidex":{"max":45},
            "Dew_Point":{"min":-22}}

# %%
#saving outliers file
filename="outliers.json"
with open(filename, 'w') as f:
    json.dump(outliers, f, indent=4)

# %%
#removing outliers
for k,v in outliers.items():
    col_name = k
    for lim,num in v.items():
        if lim == "min":
            df = df[df[col_name]>num]
        elif lim == "max":
            df = df[df[col_name]<num]

# %% [markdown]
# ### Train Test Split

# %%
# Shifting dataset
df["Target"] = df["Ontario_Demand"].shift(freq="-24h")

# %%
#Train test split
train_df = df[df.index<pd.to_datetime("July 1 2020")].dropna()
test_df = df[df.index>=pd.to_datetime("July 1 2020")].dropna()

X_train = train_df.select_dtypes(exclude=["datetime"]).drop(columns=["Target","Ontario_Demand","Weekday"])
y_train = train_df["Target"]

X_test = test_df.select_dtypes(exclude=["datetime"]).drop(columns=["Target","Ontario_Demand","Weekday"])
y_test = test_df["Target"]

# %% [markdown]
# ### Modelling

# %%
models = all_estimators("regressor")

# %%
regressors = ["ElasticNet",
              "ExtraTreesRegressor",
              "GradientBoostingRegressor",
              "HistGradientBoostingRegressor",
              "SVR",
              "Lasso",
              "RandomForestRegressor",
              "DecisionTreeRegressor",
              "Ridge"]
mod_names = []
mod_mae = []
mod_mape = []
for model in regressors:
    for m in models:
        if m[0]==model:
            mod = m[1]
            
    if model in ["SVR","Ridge","Lasso","ElasticNet"]:
        mod = make_pipeline(RobustScaler(),mod())
    else:
        mod = mod()    
    mod.fit(X_train,y_train)
    y_pred = mod.predict(X_test)
    mae = mean_absolute_error(y_true=y_test,y_pred=y_pred)
    mape = mean_absolute_percentage_error(y_true=y_test,y_pred=y_pred)
    mod_names.append(model)
    mod_mae.append(mae)
    mod_mape.append(mape)
# Out:
# Pipeline(steps=[('robustscaler', RobustScaler()), ('elasticnet', ElasticNet())]) 1633.2244893876914 0.10696550381555894
# ExtraTreesRegressor() 703.6518895001195 0.045322555682977717
# GradientBoostingRegressor() 785.9593695470651 0.05096910492834491
# HistGradientBoostingRegressor() 702.0274196345042 0.04540923163273484
# Pipeline(steps=[('robustscaler', RobustScaler()), ('svr', SVR())]) 1597.534545025058 0.10389088537261887
# /home/miky/env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.603e+08, tolerance: 1.429e+07
# Pipeline(steps=[('robustscaler', RobustScaler()), ('lasso', Lasso())]) 1350.0711935059796 0.08668690202861375
# RandomForestRegressor() 725.1728581679024 0.04669703633323705
# DecisionTreeRegressor() 963.2497010284621 0.0615748736141758
# Pipeline(steps=[('robustscaler', RobustScaler()), ('ridge', Ridge())]) 1347.345723892686 0.0865246347571774

# %%
#saving initial results
res_df = pd.DataFrame({"models":mod_names,"MAE":mod_mae,"MAPE":mod_mape})
res_df.to_csv("res_df.csv",index=False)

# %%
params = {"learning_rate":uniform(loc=0.0001,scale=1),
    "max_leaf_nodes":randint(low=1,high=20),
    "max_iter":randint(low=500,high=1500),
    "min_samples_leaf": randint(low=5,high=30),
    "max_bins":randint(low=3,high=255),
    "l2_regularization": uniform(loc=0,scale=2)
          }
tscv = TimeSeriesSplit(n_splits=5)
rscv = RandomizedSearchCV(best_mod,params,n_iter=100,
                          cv=tscv,
                          scoring="neg_mean_absolute_percentage_error",n_jobs=-1,verbose=3)

# %%
rscv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 2/5] END l2_regularization=1.5440596800704012, learning_rate=0.5727447162386814, max_bins=242, max_iter=747, max_leaf_nodes=2, min_samples_leaf=5;, score=-0.048 total time=   0.4s
# [CV 3/5] END l2_regularization=1.5440596800704012, learning_rate=0.5727447162386814, max_bins=242, max_iter=747, max_leaf_nodes=2, min_samples_leaf=5;, score=-0.050 total time=   0.5s
# [CV 4/5] END l2_regularization=1.5440596800704012, learning_rate=0.5727447162386814, max_bins=242, max_iter=747, max_leaf_nodes=2, min_samples_leaf=5;, score=-0.045 total time=   0.6s
# [CV 1/5] END l2_regularization=1.5440596800704012, learning_rate=0.5727447162386814, max_bins=242, max_iter=747, max_leaf_nodes=2, min_samples_leaf=5;, score=-0.055 total time=   0.7s
# [CV 2/5] END l2_regularization=1.3091044357427584, learning_rate=0.6543592842953605, max_bins=206, max_iter=888, max_leaf_nodes=9, min_samples_leaf=22;, score=-0.049 total time=   0.7s
# [CV 5/5] END l2_regularization=1.5440596800704012, learning_rate=0.5727447162386814, max_bins=242, max_iter=747, max_leaf_nodes=2, min_samples_leaf=5;, score=-0.062 total time=   0.8s
# [CV 1/5] END l2_regularization=0.2003139831429881, learning_rate=0.116535919205929, max_bins=29, max_iter=595, max_leaf_nodes=14, min_samples_leaf=22;, score=-0.053 total time=   1.2s
# [CV 3/5] END l2_regularization=1.3091044357427584, learning_rate=0.6543592842953605, max_bins=206, max_iter=888, max_leaf_nodes=9, min_samples_leaf=22;, score=-0.048 total time=   0.7s
# [CV 3/5] END l2_regularization=0.4998128636680428, learning_rate=0.6939397763079146, max_bins=217, max_iter=969, max_leaf_nodes=17, min_samples_leaf=10;, score=-0.049 total time=   0.4s
# [CV 3/5] END l2_regularization=0.2003139831429881, learning_rate=0.116535919205929, max_bins=29, max_iter=595, max_leaf_nodes=14, min_samples_leaf=22;, score=-0.044 total time=   1.8s
# [CV 1/5] END l2_regularization=1.3091044357427584, learning_rate=0.6543592842953605, max_bins=206, max_iter=888, max_leaf_nodes=9, min_samples_leaf=22;, score=-0.058 total time=   1.5s
# [CV 5/5] END l2_regularization=1.3091044357427584, learning_rate=0.6543592842953605, max_bins=206, max_iter=888, max_leaf_nodes=9, min_samples_leaf=22;, score=-0.059 total time=   1.1s
# [CV 2/5] END l2_regularization=0.4998128636680428, learning_rate=0.6939397763079146, max_bins=217, max_iter=969, max_leaf_nodes=17, min_samples_leaf=10;, score=-0.050 total time=   1.0s
# [CV 4/5] END l2_regularization=1.3091044357427584, learning_rate=0.6543592842953605, max_bins=206, max_iter=888, max_leaf_nodes=9, min_samples_leaf=22;, score=-0.041 total time=   1.3s
# [CV 4/5] END l2_regularization=0.2003139831429881, learning_rate=0.116535919205929, max_bins=29, max_iter=595, max_leaf_nodes=14, min_samples_leaf=22;, score=-0.037 total time=   2.0s
# [CV 2/5] END l2_regularization=0.2003139831429881, learning_rate=0.116535919205929, max_bins=29, max_iter=595, max_leaf_nodes=14, min_samples_leaf=22;, score=-0.044 total time=   2.1s
# [CV 5/5] END l2_regularization=0.2003139831429881, learning_rate=0.116535919205929, max_bins=29, max_iter=595, max_leaf_nodes=14, min_samples_leaf=22;, score=-0.056 total time=   2.3s
# [CV 4/5] END l2_regularization=0.4998128636680428, learning_rate=0.6939397763079146, max_bins=217, max_iter=969, max_leaf_nodes=17, min_samples_leaf=10;, score=-0.044 total time=   1.1s
# [CV 5/5] END l2_regularization=0.4998128636680428, learning_rate=0.6939397763079146, max_bins=217, max_iter=969, max_leaf_nodes=17, min_samples_leaf=10;, score=-0.061 total time=   1.0s
# [CV 2/5] END l2_regularization=1.3478241630042314, learning_rate=0.39089606972867375, max_bins=137, max_iter=517, max_leaf_nodes=15, min_samples_leaf=28;, score=-0.045 total time=   0.7s
# [CV 2/5] END l2_regularization=0.640456860172018, learning_rate=0.6308900620560264, max_bins=106, max_iter=1393, max_leaf_nodes=17, min_samples_leaf=5;, score=-0.050 total time=   0.5s
# [CV 1/5] END l2_regularization=1.3478241630042314, learning_rate=0.39089606972867375, max_bins=137, max_iter=517, max_leaf_nodes=15, min_samples_leaf=28;, score=-0.054 total time=   1.6s
# [CV 4/5] END l2_regularization=0.640456860172018, learning_rate=0.6308900620560264, max_bins=106, max_iter=1393, max_leaf_nodes=17, min_samples_leaf=5;, score=-0.044 total time=   1.0s
# [CV 3/5] END l2_regularization=1.3478241630042314, learning_rate=0.39089606972867375, max_bins=137, max_iter=517, max_leaf_nodes=15, min_samples_leaf=28;, score=-0.046 total time=   1.4s
# [CV 5/5] END l2_regularization=0.640456860172018, learning_rate=0.6308900620560264, max_bins=106, max_iter=1393, max_leaf_nodes=17, min_samples_leaf=5;, score=-0.059 total time=   1.2s
# [CV 3/5] END l2_regularization=0.640456860172018, learning_rate=0.6308900620560264, max_bins=106, max_iter=1393, max_leaf_nodes=17, min_samples_leaf=5;, score=-0.050 total time=   1.4s
# [CV 1/5] END l2_regularization=1.8686494999480614, learning_rate=0.023819268706218654, max_bins=50, max_iter=559, max_leaf_nodes=6, min_samples_leaf=27;, score=-0.051 total time=   0.8s
# [CV 4/5] END l2_regularization=1.3478241630042314, learning_rate=0.39089606972867375, max_bins=137, max_iter=517, max_leaf_nodes=15, min_samples_leaf=28;, score=-0.040 total time=   2.4s
# [CV 1/5] END l2_regularization=0.4998128636680428, learning_rate=0.6939397763079146, max_bins=217, max_iter=969, max_leaf_nodes=17, min_samples_leaf=10;, score=-0.059 total time=   3.7s
# [CV 5/5] END l2_regularization=1.3478241630042314, learning_rate=0.39089606972867375, max_bins=137, max_iter=517, max_leaf_nodes=15, min_samples_leaf=28;, score=-0.058 total time=   2.6s
# [CV 2/5] END l2_regularization=1.8686494999480614, learning_rate=0.023819268706218654, max_bins=50, max_iter=559, max_leaf_nodes=6, min_samples_leaf=27;, score=-0.045 total time=   1.1s
# [CV 2/5] END l2_regularization=0.5839029042215502, learning_rate=0.9445741735410985, max_bins=22, max_iter=1248, max_leaf_nodes=13, min_samples_leaf=16;, score=-0.055 total time=   0.4s
# [CV 3/5] END l2_regularization=0.5839029042215502, learning_rate=0.9445741735410985, max_bins=22, max_iter=1248, max_leaf_nodes=13, min_samples_leaf=16;, score=-0.052 total time=   0.4s
# [CV 3/5] END l2_regularization=1.8686494999480614, learning_rate=0.023819268706218654, max_bins=50, max_iter=559, max_leaf_nodes=6, min_samples_leaf=27;, score=-0.046 total time=   1.4s
# [CV 2/5] END l2_regularization=1.58261091057872, learning_rate=0.12539866951200573, max_bins=91, max_iter=1338, max_leaf_nodes=16, min_samples_leaf=27;, score=-0.043 total time=   2.9s
# [CV 4/5] END l2_regularization=1.8686494999480614, learning_rate=0.023819268706218654, max_bins=50, max_iter=559, max_leaf_nodes=6, min_samples_leaf=27;, score=-0.041 total time=   1.4s
# [CV 4/5] END l2_regularization=0.5839029042215502, learning_rate=0.9445741735410985, max_bins=22, max_iter=1248, max_leaf_nodes=13, min_samples_leaf=16;, score=-0.045 total time=   0.7s
# [CV 5/5] END l2_regularization=0.5839029042215502, learning_rate=0.9445741735410985, max_bins=22, max_iter=1248, max_leaf_nodes=13, min_samples_leaf=16;, score=-0.061 total time=   0.6s
# [CV 1/5] END l2_regularization=1.58261091057872, learning_rate=0.12539866951200573, max_bins=91, max_iter=1338, max_leaf_nodes=16, min_samples_leaf=27;, score=-0.053 total time=   3.4s
# [CV 5/5] END l2_regularization=1.8686494999480614, learning_rate=0.023819268706218654, max_bins=50, max_iter=559, max_leaf_nodes=6, min_samples_leaf=27;, score=-0.060 total time=   1.5s
# [CV 2/5] END l2_regularization=0.3012273089190556, learning_rate=0.7002895295297098, max_bins=84, max_iter=1158, max_leaf_nodes=9, min_samples_leaf=20;, score=-0.048 total time=   0.6s
# [CV 1/5] END l2_regularization=0.640456860172018, learning_rate=0.6308900620560264, max_bins=106, max_iter=1393, max_leaf_nodes=17, min_samples_leaf=5;, score=-0.061 total time=   3.9s
# [CV 3/5] END l2_regularization=0.3012273089190556, learning_rate=0.7002895295297098, max_bins=84, max_iter=1158, max_leaf_nodes=9, min_samples_leaf=20;, score=-0.050 total time=   0.5s
# [CV 3/5] END l2_regularization=1.2401608791025596, learning_rate=0.9299250604105976, max_bins=245, max_iter=1088, max_leaf_nodes=5, min_samples_leaf=12;, score=-0.048 total time=   0.2s
# [CV 2/5] END l2_regularization=1.2401608791025596, learning_rate=0.9299250604105976, max_bins=245, max_iter=1088, max_leaf_nodes=5, min_samples_leaf=12;, score=-0.047 total time=   0.4s
# [CV 4/5] END l2_regularization=0.3012273089190556, learning_rate=0.7002895295297098, max_bins=84, max_iter=1158, max_leaf_nodes=9, min_samples_leaf=20;, score=-0.041 total time=   0.7s
# [CV 5/5] END l2_regularization=0.3012273089190556, learning_rate=0.7002895295297098, max_bins=84, max_iter=1158, max_leaf_nodes=9, min_samples_leaf=20;, score=-0.059 total time=   0.7s
# [CV 4/5] END l2_regularization=1.2401608791025596, learning_rate=0.9299250604105976, max_bins=245, max_iter=1088, max_leaf_nodes=5, min_samples_leaf=12;, score=-0.041 total time=   0.5s
# [CV 2/5] END l2_regularization=1.3518026397169425, learning_rate=0.9774324426353923, max_bins=187, max_iter=1081, max_leaf_nodes=12, min_samples_leaf=27;, score=-0.053 total time=   0.3s
# [CV 3/5] END l2_regularization=1.3518026397169425, learning_rate=0.9774324426353923, max_bins=187, max_iter=1081, max_leaf_nodes=12, min_samples_leaf=27;, score=-0.053 total time=   0.3s
# [CV 5/5] END l2_regularization=1.2401608791025596, learning_rate=0.9299250604105976, max_bins=245, max_iter=1088, max_leaf_nodes=5, min_samples_leaf=12;, score=-0.058 total time=   0.7s
# [CV 1/5] END l2_regularization=0.5839029042215502, learning_rate=0.9445741735410985, max_bins=22, max_iter=1248, max_leaf_nodes=13, min_samples_leaf=16;, score=-0.070 total time=   2.3s
# [CV 5/5] END l2_regularization=1.3518026397169425, learning_rate=0.9774324426353923, max_bins=187, max_iter=1081, max_leaf_nodes=12, min_samples_leaf=27;, score=-0.062 total time=   0.4s
# [CV 1/5] END l2_regularization=0.3012273089190556, learning_rate=0.7002895295297098, max_bins=84, max_iter=1158, max_leaf_nodes=9, min_samples_leaf=20;, score=-0.066 total time=   1.8s
# [CV 1/5] END l2_regularization=0.8416416805543288, learning_rate=0.09546321130014236, max_bins=117, max_iter=1203, max_leaf_nodes=1, min_samples_leaf=25;, score=nan total time=   0.0s
# [CV 2/5] END l2_regularization=0.8416416805543288, learning_rate=0.09546321130014236, max_bins=117, max_iter=1203, max_leaf_nodes=1, min_samples_leaf=25;, score=nan total time=   0.0s
# [CV 3/5] END l2_regularization=0.8416416805543288, learning_rate=0.09546321130014236, max_bins=117, max_iter=1203, max_leaf_nodes=1, min_samples_leaf=25;, score=nan total time=   0.0s
# [CV 1/5] END l2_regularization=1.2401608791025596, learning_rate=0.9299250604105976, max_bins=245, max_iter=1088, max_leaf_nodes=5, min_samples_leaf=12;, score=-0.066 total time=   1.3s
# [CV 4/5] END l2_regularization=0.8416416805543288, learning_rate=0.09546321130014236, max_bins=117, max_iter=1203, max_leaf_nodes=1, min_samples_leaf=25;, score=nan total time=   0.0s
# [CV 5/5] END l2_regularization=0.8416416805543288, learning_rate=0.09546321130014236, max_bins=117, max_iter=1203, max_leaf_nodes=1, min_samples_leaf=25;, score=nan total time=   0.0s
# [CV 2/5] END l2_regularization=0.08841748343628386, learning_rate=0.07439752330766015, max_bins=54, max_iter=1247, max_leaf_nodes=1, min_samples_leaf=14;, score=nan total time=   0.0s
# [CV 1/5] END l2_regularization=0.08841748343628386, learning_rate=0.07439752330766015, max_bins=54, max_iter=1247, max_leaf_nodes=1, min_samples_leaf=14;, score=nan total time=   0.0s
# [CV 3/5] END l2_regularization=0.08841748343628386, learning_rate=0.07439752330766015, max_bins=54, max_iter=1247, max_leaf_nodes=1, min_samples_leaf=14;, score=nan total time=   0.0s[CV 4/5] END l2_regularization=0.08841748343628386, learning_rate=0.07439752330766015, max_bins=54, max_iter=1247, max_leaf_nodes=1, min_samples_leaf=14;, score=nan total time=   0.0s
# [CV 4/5] END l2_regularization=1.3518026397169425, learning_rate=0.9774324426353923, max_bins=187, max_iter=1081, max_leaf_nodes=12, min_samples_leaf=27;, score=-0.049 total time=   0.7s
# [CV 3/5] END l2_regularization=1.58261091057872, learning_rate=0.12539866951200573, max_bins=91, max_iter=1338, max_leaf_nodes=16, min_samples_leaf=27;, score=-0.044 total time=   4.4s
#
# [CV 5/5] END l2_regularization=0.08841748343628386, learning_rate=0.07439752330766015, max_bins=54, max_iter=1247, max_leaf_nodes=1, min_samples_leaf=14;, score=nan total time=   0.0s
# [CV 2/5] END l2_regularization=0.4953291774271993, learning_rate=0.42381414152670616, max_bins=25, max_iter=1040, max_leaf_nodes=12, min_samples_leaf=9;, score=-0.046 total time=   0.7s
# [CV 2/5] END l2_regularization=0.4625470064458743, learning_rate=0.8837782570860746, max_bins=192, max_iter=837, max_leaf_nodes=8, min_samples_leaf=24;, score=-0.049 total time=   0.4s
# [CV 3/5] END l2_regularization=0.4625470064458743, learning_rate=0.8837782570860746, max_bins=192, max_iter=837, max_leaf_nodes=8, min_samples_leaf=24;, score=-0.050 total time=   0.5s
# [CV 4/5] END l2_regularization=0.4625470064458743, learning_rate=0.8837782570860746, max_bins=192, max_iter=837, max_leaf_nodes=8, min_samples_leaf=24;, score=-0.043 total time=   0.7s
# [CV 2/5] END l2_regularization=1.5659353169221253, learning_rate=0.5258042324060521, max_bins=5, max_iter=1498, max_leaf_nodes=13, min_samples_leaf=9;, score=-0.064 total time=   0.3s
# [CV 4/5] END l2_regularization=1.58261091057872, learning_rate=0.12539866951200573, max_bins=91, max_iter=1338, max_leaf_nodes=16, min_samples_leaf=27;, score=-0.037 total time=   4.8s
# [CV 3/5] END l2_regularization=0.4953291774271993, learning_rate=0.42381414152670616, max_bins=25, max_iter=1040, max_leaf_nodes=12, min_samples_leaf=9;, score=-0.046 total time=   1.3s
# [CV 5/5] END l2_regularization=0.4625470064458743, learning_rate=0.8837782570860746, max_bins=192, max_iter=837, max_leaf_nodes=8, min_samples_leaf=24;, score=-0.061 total time=   0.8s
# [CV 5/5] END l2_regularization=1.58261091057872, learning_rate=0.12539866951200573, max_bins=91, max_iter=1338, max_leaf_nodes=16, min_samples_leaf=27;, score=-0.057 total time=   5.0s
# [CV 1/5] END l2_regularization=1.3518026397169425, learning_rate=0.9774324426353923, max_bins=187, max_iter=1081, max_leaf_nodes=12, min_samples_leaf=27;, score=-0.068 total time=   2.3s
# [CV 4/5] END l2_regularization=1.5659353169221253, learning_rate=0.5258042324060521, max_bins=5, max_iter=1498, max_leaf_nodes=13, min_samples_leaf=9;, score=-0.059 total time=   0.5s
# [CV 1/5] END l2_regularization=0.4625470064458743, learning_rate=0.8837782570860746, max_bins=192, max_iter=837, max_leaf_nodes=8, min_samples_leaf=24;, score=-0.068 total time=   1.4s
# [CV 4/5] END l2_regularization=0.4953291774271993, learning_rate=0.42381414152670616, max_bins=25, max_iter=1040, max_leaf_nodes=12, min_samples_leaf=9;, score=-0.041 total time=   1.7s
# [CV 5/5] END l2_regularization=1.5659353169221253, learning_rate=0.5258042324060521, max_bins=5, max_iter=1498, max_leaf_nodes=13, min_samples_leaf=9;, score=-0.074 total time=   0.5s
# [CV 1/5] END l2_regularization=0.4953291774271993, learning_rate=0.42381414152670616, max_bins=25, max_iter=1040, max_leaf_nodes=12, min_samples_leaf=9;, score=-0.058 total time=   2.0s
# [CV 3/5] END l2_regularization=1.5659353169221253, learning_rate=0.5258042324060521, max_bins=5, max_iter=1498, max_leaf_nodes=13, min_samples_leaf=9;, score=-0.067 total time=   0.8s
# [CV 5/5] END l2_regularization=0.4953291774271993, learning_rate=0.42381414152670616, max_bins=25, max_iter=1040, max_leaf_nodes=12, min_samples_leaf=9;, score=-0.058 total time=   2.4s
# [CV 2/5] END l2_regularization=0.3332873190721102, learning_rate=0.3705268634511807, max_bins=236, max_iter=806, max_leaf_nodes=12, min_samples_leaf=20;, score=-0.045 total time=   1.3s
# [CV 1/5] END l2_regularization=0.3332873190721102, learning_rate=0.3705268634511807, max_bins=236, max_iter=806, max_leaf_nodes=12, min_samples_leaf=20;, score=-0.055 total time=   1.5s
# [CV 3/5] END l2_regularization=0.3332873190721102, learning_rate=0.3705268634511807, max_bins=236, max_iter=806, max_leaf_nodes=12, min_samples_leaf=20;, score=-0.046 total time=   1.5s
# [CV 4/5] END l2_regularization=0.3332873190721102, learning_rate=0.3705268634511807, max_bins=236, max_iter=806, max_leaf_nodes=12, min_samples_leaf=20;, score=-0.039 total time=   1.6s
# [CV 1/5] END l2_regularization=1.314570209259235, learning_rate=0.2817543299326317, max_bins=163, max_iter=523, max_leaf_nodes=10, min_samples_leaf=23;, score=-0.054 total time=   0.9s
# [CV 5/5] END l2_regularization=0.3332873190721102, learning_rate=0.3705268634511807, max_bins=236, max_iter=806, max_leaf_nodes=12, min_samples_leaf=20;, score=-0.058 total time=   2.2s
# [CV 2/5] END l2_regularization=1.314570209259235, learning_rate=0.2817543299326317, max_bins=163, max_iter=523, max_leaf_nodes=10, min_samples_leaf=23;, score=-0.044 total time=   1.2s
# [CV 1/5] END l2_regularization=1.5659353169221253, learning_rate=0.5258042324060521, max_bins=5, max_iter=1498, max_leaf_nodes=13, min_samples_leaf=9;, score=-0.085 total time=   3.2s
# [CV 3/5] END l2_regularization=1.314570209259235, learning_rate=0.2817543299326317, max_bins=163, max_iter=523, max_leaf_nodes=10, min_samples_leaf=23;, score=-0.044 total time=   1.4s
# [CV 2/5] END l2_regularization=1.9736994868248776, learning_rate=0.625271142728492, max_bins=222, max_iter=595, max_leaf_nodes=14, min_samples_leaf=19;, score=-0.047 total time=   0.3s
# [CV 4/5] END l2_regularization=1.314570209259235, learning_rate=0.2817543299326317, max_bins=163, max_iter=523, max_leaf_nodes=10, min_samples_leaf=23;, score=-0.038 total time=   1.6s
# [CV 3/5] END l2_regularization=1.9736994868248776, learning_rate=0.625271142728492, max_bins=222, max_iter=595, max_leaf_nodes=14, min_samples_leaf=19;, score=-0.049 total time=   0.8s
# [CV 1/5] END l2_regularization=0.5248650419594898, learning_rate=0.05303527920413521, max_bins=241, max_iter=1420, max_leaf_nodes=10, min_samples_leaf=14;, score=-0.052 total time=   3.0s
# [CV 1/5] END l2_regularization=1.9736994868248776, learning_rate=0.625271142728492, max_bins=222, max_iter=595, max_leaf_nodes=14, min_samples_leaf=19;, score=-0.058 total time=   1.3s
# [CV 2/5] END l2_regularization=0.17529122094725547, learning_rate=0.8585487158624684, max_bins=73, max_iter=1014, max_leaf_nodes=4, min_samples_leaf=17;, score=-0.046 total time=   0.3s
# [CV 5/5] END l2_regularization=1.314570209259235, learning_rate=0.2817543299326317, max_bins=163, max_iter=523, max_leaf_nodes=10, min_samples_leaf=23;, score=-0.057 total time=   1.8s
# [CV 3/5] END l2_regularization=0.17529122094725547, learning_rate=0.8585487158624684, max_bins=73, max_iter=1014, max_leaf_nodes=4, min_samples_leaf=17;, score=-0.046 total time=   0.4s
# [CV 1/5] END l2_regularization=0.17529122094725547, learning_rate=0.8585487158624684, max_bins=73, max_iter=1014, max_leaf_nodes=4, min_samples_leaf=17;, score=-0.066 total time=   1.1s
# [CV 3/5] END l2_regularization=0.5248650419594898, learning_rate=0.05303527920413521, max_bins=241, max_iter=1420, max_leaf_nodes=10, min_samples_leaf=14;, score=-0.042 total time=   3.7s
# [CV 4/5] END l2_regularization=1.9736994868248776, learning_rate=0.625271142728492, max_bins=222, max_iter=595, max_leaf_nodes=14, min_samples_leaf=19;, score=-0.043 total time=   1.5s[CV 2/5] END l2_regularization=0.5248650419594898, learning_rate=0.05303527920413521, max_bins=241, max_iter=1420, max_leaf_nodes=10, min_samples_leaf=14;, score=-0.042 total time=   3.8s
#
# [CV 4/5] END l2_regularization=0.17529122094725547, learning_rate=0.8585487158624684, max_bins=73, max_iter=1014, max_leaf_nodes=4, min_samples_leaf=17;, score=-0.041 total time=   0.8s
# [CV 5/5] END l2_regularization=1.9736994868248776, learning_rate=0.625271142728492, max_bins=222, max_iter=595, max_leaf_nodes=14, min_samples_leaf=19;, score=-0.059 total time=   1.5s
# [CV 5/5] END l2_regularization=0.17529122094725547, learning_rate=0.8585487158624684, max_bins=73, max_iter=1014, max_leaf_nodes=4, min_samples_leaf=17;, score=-0.057 total time=   1.0s
# [CV 2/5] END l2_regularization=0.980128430542087, learning_rate=0.8869073270952905, max_bins=108, max_iter=699, max_leaf_nodes=3, min_samples_leaf=15;, score=-0.044 total time=   0.4s
# [CV 3/5] END l2_regularization=0.980128430542087, learning_rate=0.8869073270952905, max_bins=108, max_iter=699, max_leaf_nodes=3, min_samples_leaf=15;, score=-0.046 total time=   0.4s
# [CV 4/5] END l2_regularization=0.980128430542087, learning_rate=0.8869073270952905, max_bins=108, max_iter=699, max_leaf_nodes=3, min_samples_leaf=15;, score=-0.041 total time=   0.3s
# [CV 1/5] END l2_regularization=0.980128430542087, learning_rate=0.8869073270952905, max_bins=108, max_iter=699, max_leaf_nodes=3, min_samples_leaf=15;, score=-0.059 total time=   0.6s
# [CV 4/5] END l2_regularization=0.5248650419594898, learning_rate=0.05303527920413521, max_bins=241, max_iter=1420, max_leaf_nodes=10, min_samples_leaf=14;, score=-0.037 total time=   4.4s
# [CV 1/5] END l2_regularization=1.709822818313348, learning_rate=0.14379414540580882, max_bins=178, max_iter=883, max_leaf_nodes=8, min_samples_leaf=13;, score=-0.056 total time=   1.6s
# [CV 5/5] END l2_regularization=0.980128430542087, learning_rate=0.8869073270952905, max_bins=108, max_iter=699, max_leaf_nodes=3, min_samples_leaf=15;, score=-0.057 total time=   0.9s
# [CV 5/5] END l2_regularization=0.5248650419594898, learning_rate=0.05303527920413521, max_bins=241, max_iter=1420, max_leaf_nodes=10, min_samples_leaf=14;, score=-0.056 total time=   4.8s
# [CV 2/5] END l2_regularization=1.709822818313348, learning_rate=0.14379414540580882, max_bins=178, max_iter=883, max_leaf_nodes=8, min_samples_leaf=13;, score=-0.044 total time=   1.8s
# [CV 2/5] END l2_regularization=0.5057082617983331, learning_rate=0.44500906475480606, max_bins=249, max_iter=1391, max_leaf_nodes=6, min_samples_leaf=12;, score=-0.045 total time=   0.9s
# [CV 3/5] END l2_regularization=0.5057082617983331, learning_rate=0.44500906475480606, max_bins=249, max_iter=1391, max_leaf_nodes=6, min_samples_leaf=12;, score=-0.046 total time=   1.2s
# [CV 5/5] END l2_regularization=0.5057082617983331, learning_rate=0.44500906475480606, max_bins=249, max_iter=1391, max_leaf_nodes=6, min_samples_leaf=12;, score=-0.057 total time=   1.0s
# [CV 3/5] END l2_regularization=1.709822818313348, learning_rate=0.14379414540580882, max_bins=178, max_iter=883, max_leaf_nodes=8, min_samples_leaf=13;, score=-0.043 total time=   2.1s
# [CV 2/5] END l2_regularization=0.09916900749272473, learning_rate=0.9613492659224417, max_bins=221, max_iter=837, max_leaf_nodes=15, min_samples_leaf=16;, score=-0.051 total time=   0.3s
# [CV 3/5] END l2_regularization=0.09916900749272473, learning_rate=0.9613492659224417, max_bins=221, max_iter=837, max_leaf_nodes=15, min_samples_leaf=16;, score=-0.054 total time=   0.3s
# [CV 2/5] END l2_regularization=0.971328101449261, learning_rate=0.3147558437527863, max_bins=215, max_iter=1394, max_leaf_nodes=17, min_samples_leaf=18;, score=-0.045 total time=   0.8s
# [CV 1/5] END l2_regularization=0.17758330706723835, learning_rate=0.2945412615199756, max_bins=61, max_iter=1041, max_leaf_nodes=1, min_samples_leaf=22;, score=nan total time=   0.0s
# [CV 4/5] END l2_regularization=0.5057082617983331, learning_rate=0.44500906475480606, max_bins=249, max_iter=1391, max_leaf_nodes=6, min_samples_leaf=12;, score=-0.039 total time=   1.5s
# [CV 2/5] END l2_regularization=0.17758330706723835, learning_rate=0.2945412615199756, max_bins=61, max_iter=1041, max_leaf_nodes=1, min_samples_leaf=22;, score=nan total time=   0.0s
# [CV 3/5] END l2_regularization=0.17758330706723835, learning_rate=0.2945412615199756, max_bins=61, max_iter=1041, max_leaf_nodes=1, min_samples_leaf=22;, score=nan total time=   0.0s
# [CV 4/5] END l2_regularization=0.17758330706723835, learning_rate=0.2945412615199756, max_bins=61, max_iter=1041, max_leaf_nodes=1, min_samples_leaf=22;, score=nan total time=   0.0s
# [CV 5/5] END l2_regularization=0.17758330706723835, learning_rate=0.2945412615199756, max_bins=61, max_iter=1041, max_leaf_nodes=1, min_samples_leaf=22;, score=nan total time=   0.0s
# [CV 1/5] END l2_regularization=0.5057082617983331, learning_rate=0.44500906475480606, max_bins=249, max_iter=1391, max_leaf_nodes=6, min_samples_leaf=12;, score=-0.059 total time=   1.8s
# [CV 4/5] END l2_regularization=1.709822818313348, learning_rate=0.14379414540580882, max_bins=178, max_iter=883, max_leaf_nodes=8, min_samples_leaf=13;, score=-0.037 total time=   2.4s
# [CV 5/5] END l2_regularization=1.709822818313348, learning_rate=0.14379414540580882, max_bins=178, max_iter=883, max_leaf_nodes=8, min_samples_leaf=13;, score=-0.056 total time=   2.4s
# [CV 2/5] END l2_regularization=1.7732446443683267, learning_rate=0.813589027671507, max_bins=83, max_iter=691, max_leaf_nodes=3, min_samples_leaf=27;, score=-0.044 total time=   0.2s
# [CV 4/5] END l2_regularization=0.09916900749272473, learning_rate=0.9613492659224417, max_bins=221, max_iter=837, max_leaf_nodes=15, min_samples_leaf=16;, score=-0.046 total time=   0.4s
# [CV 3/5] END l2_regularization=1.7732446443683267, learning_rate=0.813589027671507, max_bins=83, max_iter=691, max_leaf_nodes=3, min_samples_leaf=27;, score=-0.045 total time=   0.3s
# [CV 5/5] END l2_regularization=0.09916900749272473, learning_rate=0.9613492659224417, max_bins=221, max_iter=837, max_leaf_nodes=15, min_samples_leaf=16;, score=-0.064 total time=   0.6s
# [CV 4/5] END l2_regularization=1.7732446443683267, learning_rate=0.813589027671507, max_bins=83, max_iter=691, max_leaf_nodes=3, min_samples_leaf=27;, score=-0.039 total time=   0.4s
# [CV 1/5] END l2_regularization=1.7732446443683267, learning_rate=0.813589027671507, max_bins=83, max_iter=691, max_leaf_nodes=3, min_samples_leaf=27;, score=-0.060 total time=   0.6s
# [CV 5/5] END l2_regularization=1.7732446443683267, learning_rate=0.813589027671507, max_bins=83, max_iter=691, max_leaf_nodes=3, min_samples_leaf=27;, score=-0.056 total time=   0.4s
# [CV 3/5] END l2_regularization=0.971328101449261, learning_rate=0.3147558437527863, max_bins=215, max_iter=1394, max_leaf_nodes=17, min_samples_leaf=18;, score=-0.046 total time=   1.7s
# [CV 2/5] END l2_regularization=0.0623872387242963, learning_rate=0.9597620270397885, max_bins=180, max_iter=514, max_leaf_nodes=4, min_samples_leaf=16;, score=-0.048 total time=   0.2s
# [CV 4/5] END l2_regularization=0.971328101449261, learning_rate=0.3147558437527863, max_bins=215, max_iter=1394, max_leaf_nodes=17, min_samples_leaf=18;, score=-0.039 total time=   1.8s
# [CV 2/5] END l2_regularization=1.9394662245253418, learning_rate=0.49185645154232327, max_bins=25, max_iter=1384, max_leaf_nodes=15, min_samples_leaf=26;, score=-0.046 total time=   0.8s
# [CV 1/5] END l2_regularization=0.0623872387242963, learning_rate=0.9597620270397885, max_bins=180, max_iter=514, max_leaf_nodes=4, min_samples_leaf=16;, score=-0.074 total time=   0.5s
# [CV 3/5] END l2_regularization=0.0623872387242963, learning_rate=0.9597620270397885, max_bins=180, max_iter=514, max_leaf_nodes=4, min_samples_leaf=16;, score=-0.049 total time=   0.4s
# [CV 1/5] END l2_regularization=0.09916900749272473, learning_rate=0.9613492659224417, max_bins=221, max_iter=837, max_leaf_nodes=15, min_samples_leaf=16;, score=-0.071 total time=   1.7s
# [CV 3/5] END l2_regularization=1.9394662245253418, learning_rate=0.49185645154232327, max_bins=25, max_iter=1384, max_leaf_nodes=15, min_samples_leaf=26;, score=-0.047 total time=   0.9s
# [CV 4/5] END l2_regularization=0.0623872387242963, learning_rate=0.9597620270397885, max_bins=180, max_iter=514, max_leaf_nodes=4, min_samples_leaf=16;, score=-0.041 total time=   0.6s
# [CV 5/5] END l2_regularization=0.971328101449261, learning_rate=0.3147558437527863, max_bins=215, max_iter=1394, max_leaf_nodes=17, min_samples_leaf=18;, score=-0.059 total time=   2.3s
# [CV 5/5] END l2_regularization=0.0623872387242963, learning_rate=0.9597620270397885, max_bins=180, max_iter=514, max_leaf_nodes=4, min_samples_leaf=16;, score=-0.057 total time=   0.6s
# [CV 2/5] END l2_regularization=1.3745301254289557, learning_rate=0.3610939407318613, max_bins=163, max_iter=792, max_leaf_nodes=18, min_samples_leaf=19;, score=-0.046 total time=   0.7s
# [CV 4/5] END l2_regularization=1.3745301254289557, learning_rate=0.3610939407318613, max_bins=163, max_iter=792, max_leaf_nodes=18, min_samples_leaf=19;, score=-0.039 total time=   0.8s
# [CV 1/5] END l2_regularization=0.971328101449261, learning_rate=0.3147558437527863, max_bins=215, max_iter=1394, max_leaf_nodes=17, min_samples_leaf=18;, score=-0.056 total time=   3.3s
# [CV 1/5] END l2_regularization=0.5625324017804447, learning_rate=0.33509308053509523, max_bins=174, max_iter=642, max_leaf_nodes=7, min_samples_leaf=26;, score=-0.057 total time=   0.8s
# [CV 2/5] END l2_regularization=0.5625324017804447, learning_rate=0.33509308053509523, max_bins=174, max_iter=642, max_leaf_nodes=7, min_samples_leaf=26;, score=-0.044 total time=   0.8s
# [CV 5/5] END l2_regularization=1.9394662245253418, learning_rate=0.49185645154232327, max_bins=25, max_iter=1384, max_leaf_nodes=15, min_samples_leaf=26;, score=-0.059 total time=   1.9s
# [CV 2/5] END l2_regularization=1.159812472397589, learning_rate=0.9842852331709523, max_bins=66, max_iter=623, max_leaf_nodes=3, min_samples_leaf=25;, score=-0.045 total time=   0.2s
# [CV 3/5] END l2_regularization=1.3745301254289557, learning_rate=0.3610939407318613, max_bins=163, max_iter=792, max_leaf_nodes=18, min_samples_leaf=19;, score=-0.046 total time=   1.3s
# [CV 4/5] END l2_regularization=1.9394662245253418, learning_rate=0.49185645154232327, max_bins=25, max_iter=1384, max_leaf_nodes=15, min_samples_leaf=26;, score=-0.042 total time=   2.0s
# [CV 3/5] END l2_regularization=1.159812472397589, learning_rate=0.9842852331709523, max_bins=66, max_iter=623, max_leaf_nodes=3, min_samples_leaf=25;, score=-0.047 total time=   0.2s
# [CV 1/5] END l2_regularization=1.3745301254289557, learning_rate=0.3610939407318613, max_bins=163, max_iter=792, max_leaf_nodes=18, min_samples_leaf=19;, score=-0.055 total time=   1.7s
# [CV 1/5] END l2_regularization=1.159812472397589, learning_rate=0.9842852331709523, max_bins=66, max_iter=623, max_leaf_nodes=3, min_samples_leaf=25;, score=-0.063 total time=   0.5s
# [CV 3/5] END l2_regularization=0.5625324017804447, learning_rate=0.33509308053509523, max_bins=174, max_iter=642, max_leaf_nodes=7, min_samples_leaf=26;, score=-0.045 total time=   1.1s
# [CV 1/5] END l2_regularization=1.9394662245253418, learning_rate=0.49185645154232327, max_bins=25, max_iter=1384, max_leaf_nodes=15, min_samples_leaf=26;, score=-0.059 total time=   2.5s
# [CV 4/5] END l2_regularization=1.159812472397589, learning_rate=0.9842852331709523, max_bins=66, max_iter=623, max_leaf_nodes=3, min_samples_leaf=25;, score=-0.039 total time=   0.5s
# [CV 5/5] END l2_regularization=1.159812472397589, learning_rate=0.9842852331709523, max_bins=66, max_iter=623, max_leaf_nodes=3, min_samples_leaf=25;, score=-0.057 total time=   0.6s
# [CV 5/5] END l2_regularization=1.3745301254289557, learning_rate=0.3610939407318613, max_bins=163, max_iter=792, max_leaf_nodes=18, min_samples_leaf=19;, score=-0.058 total time=   1.7s
# [CV 2/5] END l2_regularization=1.022085079676208, learning_rate=0.3877649352961242, max_bins=238, max_iter=877, max_leaf_nodes=3, min_samples_leaf=16;, score=-0.043 total time=   0.5s
# [CV 4/5] END l2_regularization=0.5625324017804447, learning_rate=0.33509308053509523, max_bins=174, max_iter=642, max_leaf_nodes=7, min_samples_leaf=26;, score=-0.039 total time=   1.3s
# [CV 5/5] END l2_regularization=0.5625324017804447, learning_rate=0.33509308053509523, max_bins=174, max_iter=642, max_leaf_nodes=7, min_samples_leaf=26;, score=-0.057 total time=   1.1s
# [CV 1/5] END l2_regularization=1.022085079676208, learning_rate=0.3877649352961242, max_bins=238, max_iter=877, max_leaf_nodes=3, min_samples_leaf=16;, score=-0.055 total time=   0.7s
# [CV 2/5] END l2_regularization=1.265415200996194, learning_rate=0.5026097465875098, max_bins=35, max_iter=627, max_leaf_nodes=14, min_samples_leaf=26;, score=-0.046 total time=   0.5s
# [CV 3/5] END l2_regularization=1.022085079676208, learning_rate=0.3877649352961242, max_bins=238, max_iter=877, max_leaf_nodes=3, min_samples_leaf=16;, score=-0.044 total time=   0.8s
# [CV 2/5] END l2_regularization=1.6751487315572569, learning_rate=0.9808575718289617, max_bins=135, max_iter=1320, max_leaf_nodes=6, min_samples_leaf=11;, score=-0.048 total time=   0.3s
# [CV 3/5] END l2_regularization=1.6751487315572569, learning_rate=0.9808575718289617, max_bins=135, max_iter=1320, max_leaf_nodes=6, min_samples_leaf=11;, score=-0.051 total time=   0.3s
# [CV 4/5] END l2_regularization=1.6751487315572569, learning_rate=0.9808575718289617, max_bins=135, max_iter=1320, max_leaf_nodes=6, min_samples_leaf=11;, score=-0.042 total time=   0.2s
# [CV 4/5] END l2_regularization=1.022085079676208, learning_rate=0.3877649352961242, max_bins=238, max_iter=877, max_leaf_nodes=3, min_samples_leaf=16;, score=-0.039 total time=   0.8s
# [CV 3/5] END l2_regularization=1.265415200996194, learning_rate=0.5026097465875098, max_bins=35, max_iter=627, max_leaf_nodes=14, min_samples_leaf=26;, score=-0.047 total time=   0.9s
# [CV 2/5] END l2_regularization=1.8887288931432502, learning_rate=0.7112652471316662, max_bins=28, max_iter=675, max_leaf_nodes=10, min_samples_leaf=20;, score=-0.050 total time=   0.4s
# [CV 1/5] END l2_regularization=1.265415200996194, learning_rate=0.5026097465875098, max_bins=35, max_iter=627, max_leaf_nodes=14, min_samples_leaf=26;, score=-0.055 total time=   1.1s
# [CV 3/5] END l2_regularization=1.8887288931432502, learning_rate=0.7112652471316662, max_bins=28, max_iter=675, max_leaf_nodes=10, min_samples_leaf=20;, score=-0.049 total time=   0.5s
# [CV 5/5] END l2_regularization=1.022085079676208, learning_rate=0.3877649352961242, max_bins=238, max_iter=877, max_leaf_nodes=3, min_samples_leaf=16;, score=-0.056 total time=   1.3s
# [CV 4/5] END l2_regularization=1.8887288931432502, learning_rate=0.7112652471316662, max_bins=28, max_iter=675, max_leaf_nodes=10, min_samples_leaf=20;, score=-0.042 total time=   0.6s
# [CV 5/5] END l2_regularization=1.6751487315572569, learning_rate=0.9808575718289617, max_bins=135, max_iter=1320, max_leaf_nodes=6, min_samples_leaf=11;, score=-0.060 total time=   0.8s
# [CV 1/5] END l2_regularization=1.8887288931432502, learning_rate=0.7112652471316662, max_bins=28, max_iter=675, max_leaf_nodes=10, min_samples_leaf=20;, score=-0.063 total time=   1.0s
# [CV 4/5] END l2_regularization=1.265415200996194, learning_rate=0.5026097465875098, max_bins=35, max_iter=627, max_leaf_nodes=14, min_samples_leaf=26;, score=-0.040 total time=   1.4s
# [CV 1/5] END l2_regularization=1.6751487315572569, learning_rate=0.9808575718289617, max_bins=135, max_iter=1320, max_leaf_nodes=6, min_samples_leaf=11;, score=-0.069 total time=   1.5s
# [CV 5/5] END l2_regularization=1.8887288931432502, learning_rate=0.7112652471316662, max_bins=28, max_iter=675, max_leaf_nodes=10, min_samples_leaf=20;, score=-0.059 total time=   1.0s
# [CV 2/5] END l2_regularization=0.037259324749307154, learning_rate=0.5327227027241853, max_bins=161, max_iter=1281, max_leaf_nodes=7, min_samples_leaf=16;, score=-0.046 total time=   0.4s
# [CV 5/5] END l2_regularization=1.265415200996194, learning_rate=0.5026097465875098, max_bins=35, max_iter=627, max_leaf_nodes=14, min_samples_leaf=26;, score=-0.059 total time=   1.6s
# [CV 2/5] END l2_regularization=1.5854623464686177, learning_rate=0.7461842574110076, max_bins=41, max_iter=946, max_leaf_nodes=12, min_samples_leaf=24;, score=-0.050 total time=   0.4s
# [CV 3/5] END l2_regularization=0.8876146783701215, learning_rate=0.2413708268135517, max_bins=209, max_iter=1103, max_leaf_nodes=12, min_samples_leaf=10;, score=-0.044 total time=   1.2s
# [CV 3/5] END l2_regularization=0.037259324749307154, learning_rate=0.5327227027241853, max_bins=161, max_iter=1281, max_leaf_nodes=7, min_samples_leaf=16;, score=-0.047 total time=   0.7s
# [CV 4/5] END l2_regularization=0.037259324749307154, learning_rate=0.5327227027241853, max_bins=161, max_iter=1281, max_leaf_nodes=7, min_samples_leaf=16;, score=-0.039 total time=   0.7s
# [CV 2/5] END l2_regularization=0.8876146783701215, learning_rate=0.2413708268135517, max_bins=209, max_iter=1103, max_leaf_nodes=12, min_samples_leaf=10;, score=-0.044 total time=   1.3s
# [CV 5/5] END l2_regularization=0.037259324749307154, learning_rate=0.5327227027241853, max_bins=161, max_iter=1281, max_leaf_nodes=7, min_samples_leaf=16;, score=-0.057 total time=   0.8s
# [CV 3/5] END l2_regularization=1.5854623464686177, learning_rate=0.7461842574110076, max_bins=41, max_iter=946, max_leaf_nodes=12, min_samples_leaf=24;, score=-0.051 total time=   0.8s
# [CV 4/5] END l2_regularization=0.8876146783701215, learning_rate=0.2413708268135517, max_bins=209, max_iter=1103, max_leaf_nodes=12, min_samples_leaf=10;, score=-0.038 total time=   1.5s
# [CV 4/5] END l2_regularization=1.5854623464686177, learning_rate=0.7461842574110076, max_bins=41, max_iter=946, max_leaf_nodes=12, min_samples_leaf=24;, score=-0.044 total time=   0.7s
# [CV 1/5] END l2_regularization=0.037259324749307154, learning_rate=0.5327227027241853, max_bins=161, max_iter=1281, max_leaf_nodes=7, min_samples_leaf=16;, score=-0.063 total time=   1.6s
# [CV 1/5] END l2_regularization=0.8876146783701215, learning_rate=0.2413708268135517, max_bins=209, max_iter=1103, max_leaf_nodes=12, min_samples_leaf=10;, score=-0.055 total time=   1.9s
# [CV 1/5] END l2_regularization=1.5854623464686177, learning_rate=0.7461842574110076, max_bins=41, max_iter=946, max_leaf_nodes=12, min_samples_leaf=24;, score=-0.061 total time=   1.5s
# [CV 2/5] END l2_regularization=0.2368215695851248, learning_rate=0.33335397169555336, max_bins=167, max_iter=1467, max_leaf_nodes=13, min_samples_leaf=21;, score=-0.045 total time=   1.0s
# [CV 5/5] END l2_regularization=1.5854623464686177, learning_rate=0.7461842574110076, max_bins=41, max_iter=946, max_leaf_nodes=12, min_samples_leaf=24;, score=-0.062 total time=   1.1s
# [CV 2/5] END l2_regularization=0.012195953857997432, learning_rate=0.5757278167470166, max_bins=36, max_iter=1077, max_leaf_nodes=15, min_samples_leaf=5;, score=-0.048 total time=   0.4s
# [CV 3/5] END l2_regularization=0.2368215695851248, learning_rate=0.33335397169555336, max_bins=167, max_iter=1467, max_leaf_nodes=13, min_samples_leaf=21;, score=-0.047 total time=   1.6s
# [CV 1/5] END l2_regularization=1.5081219764816307, learning_rate=0.27035005321665506, max_bins=101, max_iter=585, max_leaf_nodes=19, min_samples_leaf=14;, score=-0.053 total time=   1.3s
# [CV 5/5] END l2_regularization=0.2368215695851248, learning_rate=0.33335397169555336, max_bins=167, max_iter=1467, max_leaf_nodes=13, min_samples_leaf=21;, score=-0.057 total time=   1.4s
# [CV 3/5] END l2_regularization=1.5081219764816307, learning_rate=0.27035005321665506, max_bins=101, max_iter=585, max_leaf_nodes=19, min_samples_leaf=14;, score=-0.045 total time=   1.2s
# [CV 2/5] END l2_regularization=1.5081219764816307, learning_rate=0.27035005321665506, max_bins=101, max_iter=585, max_leaf_nodes=19, min_samples_leaf=14;, score=-0.046 total time=   1.4s
# [CV 5/5] END l2_regularization=0.8876146783701215, learning_rate=0.2413708268135517, max_bins=209, max_iter=1103, max_leaf_nodes=12, min_samples_leaf=10;, score=-0.056 total time=   3.1s
# [CV 2/5] END l2_regularization=1.2538760756384335, learning_rate=0.9207043056090677, max_bins=67, max_iter=1063, max_leaf_nodes=15, min_samples_leaf=15;, score=-0.054 total time=   0.3s
# [CV 3/5] END l2_regularization=1.2538760756384335, learning_rate=0.9207043056090677, max_bins=67, max_iter=1063, max_leaf_nodes=15, min_samples_leaf=15;, score=-0.052 total time=   0.3s
# [CV 3/5] END l2_regularization=0.012195953857997432, learning_rate=0.5757278167470166, max_bins=36, max_iter=1077, max_leaf_nodes=15, min_samples_leaf=5;, score=-0.049 total time=   0.8s
# [CV 4/5] END l2_regularization=0.2368215695851248, learning_rate=0.33335397169555336, max_bins=167, max_iter=1467, max_leaf_nodes=13, min_samples_leaf=21;, score=-0.039 total time=   2.0s
# [CV 5/5] END l2_regularization=0.012195953857997432, learning_rate=0.5757278167470166, max_bins=36, max_iter=1077, max_leaf_nodes=15, min_samples_leaf=5;, score=-0.059 total time=   0.6s
# [CV 2/5] END l2_regularization=0.4435751376707553, learning_rate=0.9883087331394322, max_bins=222, max_iter=533, max_leaf_nodes=2, min_samples_leaf=10;, score=-0.049 total time=   0.1s
# [CV 4/5] END l2_regularization=1.5081219764816307, learning_rate=0.27035005321665506, max_bins=101, max_iter=585, max_leaf_nodes=19, min_samples_leaf=14;, score=-0.039 total time=   1.8s
# [CV 4/5] END l2_regularization=1.2538760756384335, learning_rate=0.9207043056090677, max_bins=67, max_iter=1063, max_leaf_nodes=15, min_samples_leaf=15;, score=-0.045 total time=   0.4s
# [CV 1/5] END l2_regularization=0.2368215695851248, learning_rate=0.33335397169555336, max_bins=167, max_iter=1467, max_leaf_nodes=13, min_samples_leaf=21;, score=-0.058 total time=   2.5s
# [CV 3/5] END l2_regularization=0.4435751376707553, learning_rate=0.9883087331394322, max_bins=222, max_iter=533, max_leaf_nodes=2, min_samples_leaf=10;, score=-0.051 total time=   0.3s
# [CV 4/5] END l2_regularization=0.4435751376707553, learning_rate=0.9883087331394322, max_bins=222, max_iter=533, max_leaf_nodes=2, min_samples_leaf=10;, score=-0.045 total time=   0.3s
# [CV 5/5] END l2_regularization=1.5081219764816307, learning_rate=0.27035005321665506, max_bins=101, max_iter=585, max_leaf_nodes=19, min_samples_leaf=14;, score=-0.057 total time=   1.6s
# [CV 5/5] END l2_regularization=1.2538760756384335, learning_rate=0.9207043056090677, max_bins=67, max_iter=1063, max_leaf_nodes=15, min_samples_leaf=15;, score=-0.064 total time=   0.5s
# [CV 1/5] END l2_regularization=0.4435751376707553, learning_rate=0.9883087331394322, max_bins=222, max_iter=533, max_leaf_nodes=2, min_samples_leaf=10;, score=-0.056 total time=   0.4s
# [CV 4/5] END l2_regularization=0.012195953857997432, learning_rate=0.5757278167470166, max_bins=36, max_iter=1077, max_leaf_nodes=15, min_samples_leaf=5;, score=-0.042 total time=   0.9s
# [CV 5/5] END l2_regularization=0.4435751376707553, learning_rate=0.9883087331394322, max_bins=222, max_iter=533, max_leaf_nodes=2, min_samples_leaf=10;, score=-0.062 total time=   0.4s
# [CV 1/5] END l2_regularization=0.012195953857997432, learning_rate=0.5757278167470166, max_bins=36, max_iter=1077, max_leaf_nodes=15, min_samples_leaf=5;, score=-0.063 total time=   1.9s
# [CV 2/5] END l2_regularization=1.044286627875515, learning_rate=0.4026898478726699, max_bins=119, max_iter=1412, max_leaf_nodes=8, min_samples_leaf=26;, score=-0.044 total time=   0.8s
# [CV 3/5] END l2_regularization=1.044286627875515, learning_rate=0.4026898478726699, max_bins=119, max_iter=1412, max_leaf_nodes=8, min_samples_leaf=26;, score=-0.046 total time=   0.8s
# [CV 2/5] END l2_regularization=0.19593913645635697, learning_rate=0.27481767249701206, max_bins=191, max_iter=556, max_leaf_nodes=17, min_samples_leaf=26;, score=-0.046 total time=   1.0s
# [CV 4/5] END l2_regularization=1.044286627875515, learning_rate=0.4026898478726699, max_bins=119, max_iter=1412, max_leaf_nodes=8, min_samples_leaf=26;, score=-0.039 total time=   1.0s
# [CV 1/5] END l2_regularization=0.19593913645635697, learning_rate=0.27481767249701206, max_bins=191, max_iter=556, max_leaf_nodes=17, min_samples_leaf=26;, score=-0.053 total time=   1.2s
# [CV 1/5] END l2_regularization=0.5848205534734969, learning_rate=0.8923090107680647, max_bins=79, max_iter=1306, max_leaf_nodes=1, min_samples_leaf=11;, score=nan total time=   0.0s
# [CV 2/5] END l2_regularization=0.5848205534734969, learning_rate=0.8923090107680647, max_bins=79, max_iter=1306, max_leaf_nodes=1, min_samples_leaf=11;, score=nan total time=   0.0s
# [CV 3/5] END l2_regularization=0.5848205534734969, learning_rate=0.8923090107680647, max_bins=79, max_iter=1306, max_leaf_nodes=1, min_samples_leaf=11;, score=nan total time=   0.0s
# [CV 4/5] END l2_regularization=0.5848205534734969, learning_rate=0.8923090107680647, max_bins=79, max_iter=1306, max_leaf_nodes=1, min_samples_leaf=11;, score=nan total time=   0.0s
# [CV 5/5] END l2_regularization=0.5848205534734969, learning_rate=0.8923090107680647, max_bins=79, max_iter=1306, max_leaf_nodes=1, min_samples_leaf=11;, score=nan total time=   0.0s
# [CV 1/5] END l2_regularization=1.2538760756384335, learning_rate=0.9207043056090677, max_bins=67, max_iter=1063, max_leaf_nodes=15, min_samples_leaf=15;, score=-0.071 total time=   2.0s
# [CV 5/5] END l2_regularization=1.044286627875515, learning_rate=0.4026898478726699, max_bins=119, max_iter=1412, max_leaf_nodes=8, min_samples_leaf=26;, score=-0.056 total time=   1.1s
# [CV 2/5] END l2_regularization=1.3772015544147551, learning_rate=0.6248473827137526, max_bins=34, max_iter=1175, max_leaf_nodes=16, min_samples_leaf=18;, score=-0.048 total time=   0.5s
# [CV 3/5] END l2_regularization=0.19593913645635697, learning_rate=0.27481767249701206, max_bins=191, max_iter=556, max_leaf_nodes=17, min_samples_leaf=26;, score=-0.046 total time=   1.6s
# [CV 3/5] END l2_regularization=1.3772015544147551, learning_rate=0.6248473827137526, max_bins=34, max_iter=1175, max_leaf_nodes=16, min_samples_leaf=18;, score=-0.049 total time=   0.7s
# [CV 4/5] END l2_regularization=1.3772015544147551, learning_rate=0.6248473827137526, max_bins=34, max_iter=1175, max_leaf_nodes=16, min_samples_leaf=18;, score=-0.042 total time=   0.8s
# [CV 5/5] END l2_regularization=0.19593913645635697, learning_rate=0.27481767249701206, max_bins=191, max_iter=556, max_leaf_nodes=17, min_samples_leaf=26;, score=-0.057 total time=   1.7s
# [CV 4/5] END l2_regularization=0.19593913645635697, learning_rate=0.27481767249701206, max_bins=191, max_iter=556, max_leaf_nodes=17, min_samples_leaf=26;, score=-0.039 total time=   1.7s
# [CV 2/5] END l2_regularization=1.6461333495383608, learning_rate=0.587131046867751, max_bins=170, max_iter=767, max_leaf_nodes=16, min_samples_leaf=28;, score=-0.047 total time=   0.6s
# [CV 1/5] END l2_regularization=1.044286627875515, learning_rate=0.4026898478726699, max_bins=119, max_iter=1412, max_leaf_nodes=8, min_samples_leaf=26;, score=-0.062 total time=   1.9s
# [CV 3/5] END l2_regularization=1.6461333495383608, learning_rate=0.587131046867751, max_bins=170, max_iter=767, max_leaf_nodes=16, min_samples_leaf=28;, score=-0.048 total time=   0.8s
# [CV 4/5] END l2_regularization=1.6461333495383608, learning_rate=0.587131046867751, max_bins=170, max_iter=767, max_leaf_nodes=16, min_samples_leaf=28;, score=-0.041 total time=   0.8s
# [CV 2/5] END l2_regularization=0.5851455618427523, learning_rate=0.9706457008308695, max_bins=11, max_iter=1192, max_leaf_nodes=12, min_samples_leaf=10;, score=-0.059 total time=   0.2s
# [CV 5/5] END l2_regularization=1.3772015544147551, learning_rate=0.6248473827137526, max_bins=34, max_iter=1175, max_leaf_nodes=16, min_samples_leaf=18;, score=-0.060 total time=   1.3s
# [CV 5/5] END l2_regularization=1.6461333495383608, learning_rate=0.587131046867751, max_bins=170, max_iter=767, max_leaf_nodes=16, min_samples_leaf=28;, score=-0.060 total time=   0.9s
# [CV 1/5] END l2_regularization=1.5148492533893645, learning_rate=0.2018734118041312, max_bins=51, max_iter=956, max_leaf_nodes=4, min_samples_leaf=25;, score=-0.056 total time=   0.9s
# [CV 4/5] END l2_regularization=0.5851455618427523, learning_rate=0.9706457008308695, max_bins=11, max_iter=1192, max_leaf_nodes=12, min_samples_leaf=10;, score=-0.049 total time=   0.3s
# [CV 1/5] END l2_regularization=1.3772015544147551, learning_rate=0.6248473827137526, max_bins=34, max_iter=1175, max_leaf_nodes=16, min_samples_leaf=18;, score=-0.061 total time=   2.2s
# [CV 3/5] END l2_regularization=0.5851455618427523, learning_rate=0.9706457008308695, max_bins=11, max_iter=1192, max_leaf_nodes=12, min_samples_leaf=10;, score=-0.057 total time=   0.4s
# ...
# [CV 3/5] END l2_regularization=0.10676273096795552, learning_rate=0.16434936163475844, max_bins=157, max_iter=914, max_leaf_nodes=4, min_samples_leaf=25;, score=-0.043 total time=   0.8s
# [CV 2/5] END l2_regularization=0.10676273096795552, learning_rate=0.16434936163475844, max_bins=157, max_iter=914, max_leaf_nodes=4, min_samples_leaf=25;, score=-0.043 total time=   1.2s
# [CV 3/5] END l2_regularization=0.9483032007578429, learning_rate=0.22882290404691497, max_bins=139, max_iter=859, max_leaf_nodes=10, min_samples_leaf=23;, score=-0.046 total time=   2.0s
# [CV 5/5] END l2_regularization=0.6855992787409997, learning_rate=0.14204079602020825, max_bins=214, max_iter=1413, max_leaf_nodes=7, min_samples_leaf=17;, score=-0.056 total time=   2.5s
# [CV 4/5] END l2_regularization=0.6855992787409997, learning_rate=0.14204079602020825, max_bins=214, max_iter=1413, max_leaf_nodes=7, min_samples_leaf=17;, score=-0.038 total time=   2.8s
# [CV 4/5] END l2_regularization=0.9483032007578429, learning_rate=0.22882290404691497, max_bins=139, max_iter=859, max_leaf_nodes=10, min_samples_leaf=23;, score=-0.038 total time=   2.4s
# [CV 5/5] END l2_regularization=0.9483032007578429, learning_rate=0.22882290404691497, max_bins=139, max_iter=859, max_leaf_nodes=10, min_samples_leaf=23;, score=-0.056 total time=   2.4s
# [CV 3/5] END l2_regularization=0.6855992787409997, learning_rate=0.14204079602020825, max_bins=214, max_iter=1413, max_leaf_nodes=7, min_samples_leaf=17;, score=-0.044 total time=   3.2s
# [CV 4/5] END l2_regularization=0.10676273096795552, learning_rate=0.16434936163475844, max_bins=157, max_iter=914, max_leaf_nodes=4, min_samples_leaf=25;, score=-0.038 total time=   1.5s
# [CV 2/5] END l2_regularization=0.3759625717166104, learning_rate=0.21782132778470087, max_bins=159, max_iter=1416, max_leaf_nodes=16, min_samples_leaf=7;, score=-0.044 total time=   1.3s
# [CV 5/5] END l2_regularization=0.10676273096795552, learning_rate=0.16434936163475844, max_bins=157, max_iter=914, max_leaf_nodes=4, min_samples_leaf=25;, score=-0.056 total time=   1.7s
# [CV 3/5] END l2_regularization=0.3759625717166104, learning_rate=0.21782132778470087, max_bins=159, max_iter=1416, max_leaf_nodes=16, min_samples_leaf=7;, score=-0.044 total time=   1.7s
# [CV 3/5] END l2_regularization=0.9137970421956965, learning_rate=0.4348341018925014, max_bins=88, max_iter=1324, max_leaf_nodes=5, min_samples_leaf=20;, score=-0.045 total time=   0.6s
# [CV 2/5] END l2_regularization=0.9137970421956965, learning_rate=0.4348341018925014, max_bins=88, max_iter=1324, max_leaf_nodes=5, min_samples_leaf=20;, score=-0.045 total time=   0.9s
# [CV 1/5] END l2_regularization=0.9137970421956965, learning_rate=0.4348341018925014, max_bins=88, max_iter=1324, max_leaf_nodes=5, min_samples_leaf=20;, score=-0.061 total time=   1.3s
# [CV 2/5] END l2_regularization=1.8999137915679345, learning_rate=0.44146702374040214, max_bins=242, max_iter=1446, max_leaf_nodes=11, min_samples_leaf=8;, score=-0.045 total time=   0.2s
# [CV 4/5] END l2_regularization=0.3759625717166104, learning_rate=0.21782132778470087, max_bins=159, max_iter=1416, max_leaf_nodes=16, min_samples_leaf=7;, score=-0.038 total time=   2.4s
# [CV 4/5] END l2_regularization=0.9137970421956965, learning_rate=0.4348341018925014, max_bins=88, max_iter=1324, max_leaf_nodes=5, min_samples_leaf=20;, score=-0.039 total time=   1.0s
# [CV 1/5] END l2_regularization=1.7627770994901755, learning_rate=0.0839691488469876, max_bins=135, max_iter=1235, max_leaf_nodes=15, min_samples_leaf=21;, score=-0.052 total time=   2.6s
# [CV 5/5] END l2_regularization=0.3759625717166104, learning_rate=0.21782132778470087, max_bins=159, max_iter=1416, max_leaf_nodes=16, min_samples_leaf=7;, score=-0.057 total time=   2.8s
# [CV 1/5] END l2_regularization=0.3759625717166104, learning_rate=0.21782132778470087, max_bins=159, max_iter=1416, max_leaf_nodes=16, min_samples_leaf=7;, score=-0.056 total time=   3.5s
# [CV 5/5] END l2_regularization=0.9137970421956965, learning_rate=0.4348341018925014, max_bins=88, max_iter=1324, max_leaf_nodes=5, min_samples_leaf=20;, score=-0.056 total time=   1.3s
# [CV 3/5] END l2_regularization=1.8999137915679345, learning_rate=0.44146702374040214, max_bins=242, max_iter=1446, max_leaf_nodes=11, min_samples_leaf=8;, score=-0.047 total time=   0.9s
# [CV 5/5] END l2_regularization=1.8999137915679345, learning_rate=0.44146702374040214, max_bins=242, max_iter=1446, max_leaf_nodes=11, min_samples_leaf=8;, score=-0.058 total time=   0.8s
# [CV 4/5] END l2_regularization=1.8999137915679345, learning_rate=0.44146702374040214, max_bins=242, max_iter=1446, max_leaf_nodes=11, min_samples_leaf=8;, score=-0.041 total time=   1.1s
# [CV 2/5] END l2_regularization=1.7627770994901755, learning_rate=0.0839691488469876, max_bins=135, max_iter=1235, max_leaf_nodes=15, min_samples_leaf=21;, score=-0.043 total time=   3.2s
# [CV 2/5] END l2_regularization=1.9990817676303547, learning_rate=0.23075878495115698, max_bins=129, max_iter=1065, max_leaf_nodes=19, min_samples_leaf=24;, score=-0.043 total time=   0.8s
# [CV 3/5] END l2_regularization=1.7627770994901755, learning_rate=0.0839691488469876, max_bins=135, max_iter=1235, max_leaf_nodes=15, min_samples_leaf=21;, score=-0.043 total time=   3.4s
# [CV 2/5] END l2_regularization=1.656294319101242, learning_rate=0.5052426658896774, max_bins=14, max_iter=1110, max_leaf_nodes=4, min_samples_leaf=26;, score=-0.048 total time=   0.3s
# [CV 4/5] END l2_regularization=1.7627770994901755, learning_rate=0.0839691488469876, max_bins=135, max_iter=1235, max_leaf_nodes=15, min_samples_leaf=21;, score=-0.037 total time=   3.5s
# [CV 4/5] END l2_regularization=1.656294319101242, learning_rate=0.5052426658896774, max_bins=14, max_iter=1110, max_leaf_nodes=4, min_samples_leaf=26;, score=-0.040 total time=   0.5s
# [CV 3/5] END l2_regularization=1.656294319101242, learning_rate=0.5052426658896774, max_bins=14, max_iter=1110, max_leaf_nodes=4, min_samples_leaf=26;, score=-0.047 total time=   0.7s
# [CV 1/5] END l2_regularization=1.8999137915679345, learning_rate=0.44146702374040214, max_bins=242, max_iter=1446, max_leaf_nodes=11, min_samples_leaf=8;, score=-0.057 total time=   2.4s
# [CV 2/5] END l2_regularization=1.6577692938048454, learning_rate=0.5003506093788568, max_bins=7, max_iter=1411, max_leaf_nodes=11, min_samples_leaf=23;, score=-0.053 total time=   0.4s
# [CV 1/5] END l2_regularization=1.656294319101242, learning_rate=0.5052426658896774, max_bins=14, max_iter=1110, max_leaf_nodes=4, min_samples_leaf=26;, score=-0.064 total time=   1.0s
# [CV 4/5] END l2_regularization=1.9990817676303547, learning_rate=0.23075878495115698, max_bins=129, max_iter=1065, max_leaf_nodes=19, min_samples_leaf=24;, score=-0.038 total time=   1.5s
# [CV 3/5] END l2_regularization=1.6577692938048454, learning_rate=0.5003506093788568, max_bins=7, max_iter=1411, max_leaf_nodes=11, min_samples_leaf=23;, score=-0.056 total time=   0.6s
# [CV 5/5] END l2_regularization=1.7627770994901755, learning_rate=0.0839691488469876, max_bins=135, max_iter=1235, max_leaf_nodes=15, min_samples_leaf=21;, score=-0.056 total time=   4.3s
# [CV 2/5] END l2_regularization=0.8265269909385382, learning_rate=0.5069534871276542, max_bins=254, max_iter=997, max_leaf_nodes=11, min_samples_leaf=12;, score=-0.046 total time=   0.5s
# [CV 4/5] END l2_regularization=1.6577692938048454, learning_rate=0.5003506093788568, max_bins=7, max_iter=1411, max_leaf_nodes=11, min_samples_leaf=23;, score=-0.051 total time=   0.8s
# [CV 1/5] END l2_regularization=1.9990817676303547, learning_rate=0.23075878495115698, max_bins=129, max_iter=1065, max_leaf_nodes=19, min_samples_leaf=24;, score=-0.054 total time=   2.4s
# [CV 4/5] END l2_regularization=0.8265269909385382, learning_rate=0.5069534871276542, max_bins=254, max_iter=997, max_leaf_nodes=11, min_samples_leaf=12;, score=-0.040 total time=   0.8s
# [CV 5/5] END l2_regularization=1.656294319101242, learning_rate=0.5052426658896774, max_bins=14, max_iter=1110, max_leaf_nodes=4, min_samples_leaf=26;, score=-0.058 total time=   1.6s
# [CV 5/5] END l2_regularization=0.8265269909385382, learning_rate=0.5069534871276542, max_bins=254, max_iter=997, max_leaf_nodes=11, min_samples_leaf=12;, score=-0.059 total time=   0.6s
# [CV 3/5] END l2_regularization=1.9990817676303547, learning_rate=0.23075878495115698, max_bins=129, max_iter=1065, max_leaf_nodes=19, min_samples_leaf=24;, score=-0.045 total time=   2.6s
# [CV 3/5] END l2_regularization=0.8265269909385382, learning_rate=0.5069534871276542, max_bins=254, max_iter=997, max_leaf_nodes=11, min_samples_leaf=12;, score=-0.049 total time=   1.1s
# [CV 5/5] END l2_regularization=1.6577692938048454, learning_rate=0.5003506093788568, max_bins=7, max_iter=1411, max_leaf_nodes=11, min_samples_leaf=23;, score=-0.070 total time=   1.3s
# [CV 2/5] END l2_regularization=1.5576484993327115, learning_rate=0.40124562860940705, max_bins=207, max_iter=770, max_leaf_nodes=13, min_samples_leaf=19;, score=-0.045 total time=   0.7s
# [CV 1/5] END l2_regularization=1.5334080920736977, learning_rate=0.5260620603571315, max_bins=26, max_iter=545, max_leaf_nodes=2, min_samples_leaf=7;, score=-0.055 total time=   0.4s
# [CV 2/5] END l2_regularization=1.5334080920736977, learning_rate=0.5260620603571315, max_bins=26, max_iter=545, max_leaf_nodes=2, min_samples_leaf=7;, score=-0.049 total time=   0.4s
# [CV 1/5] END l2_regularization=1.6577692938048454, learning_rate=0.5003506093788568, max_bins=7, max_iter=1411, max_leaf_nodes=11, min_samples_leaf=23;, score=-0.066 total time=   2.1s
# [CV 4/5] END l2_regularization=1.5334080920736977, learning_rate=0.5260620603571315, max_bins=26, max_iter=545, max_leaf_nodes=2, min_samples_leaf=7;, score=-0.045 total time=   0.5s
# [CV 1/5] END l2_regularization=0.8265269909385382, learning_rate=0.5069534871276542, max_bins=254, max_iter=997, max_leaf_nodes=11, min_samples_leaf=12;, score=-0.057 total time=   1.6s
# [CV 5/5] END l2_regularization=1.9990817676303547, learning_rate=0.23075878495115698, max_bins=129, max_iter=1065, max_leaf_nodes=19, min_samples_leaf=24;, score=-0.056 total time=   2.9s
# [CV 3/5] END l2_regularization=1.5334080920736977, learning_rate=0.5260620603571315, max_bins=26, max_iter=545, max_leaf_nodes=2, min_samples_leaf=7;, score=-0.050 total time=   0.5s
# [CV 3/5] END l2_regularization=1.5576484993327115, learning_rate=0.40124562860940705, max_bins=207, max_iter=770, max_leaf_nodes=13, min_samples_leaf=19;, score=-0.046 total time=   1.0s
# [CV 2/5] END l2_regularization=0.5930660910779484, learning_rate=0.8672514220440882, max_bins=95, max_iter=1003, max_leaf_nodes=11, min_samples_leaf=16;, score=-0.049 total time=   0.3s
# [CV 4/5] END l2_regularization=1.5576484993327115, learning_rate=0.40124562860940705, max_bins=207, max_iter=770, max_leaf_nodes=13, min_samples_leaf=19;, score=-0.040 total time=   0.8s
# [CV 5/5] END l2_regularization=1.5334080920736977, learning_rate=0.5260620603571315, max_bins=26, max_iter=545, max_leaf_nodes=2, min_samples_leaf=7;, score=-0.062 total time=   0.6s
# [CV 1/5] END l2_regularization=1.5576484993327115, learning_rate=0.40124562860940705, max_bins=207, max_iter=770, max_leaf_nodes=13, min_samples_leaf=19;, score=-0.058 total time=   1.3s
# [CV 3/5] END l2_regularization=0.5930660910779484, learning_rate=0.8672514220440882, max_bins=95, max_iter=1003, max_leaf_nodes=11, min_samples_leaf=16;, score=-0.052 total time=   0.4s
# [CV 5/5] END l2_regularization=0.5930660910779484, learning_rate=0.8672514220440882, max_bins=95, max_iter=1003, max_leaf_nodes=11, min_samples_leaf=16;, score=-0.060 total time=   0.4s
# [CV 4/5] END l2_regularization=0.5930660910779484, learning_rate=0.8672514220440882, max_bins=95, max_iter=1003, max_leaf_nodes=11, min_samples_leaf=16;, score=-0.044 total time=   0.4s
# [CV 1/5] END l2_regularization=0.5930660910779484, learning_rate=0.8672514220440882, max_bins=95, max_iter=1003, max_leaf_nodes=11, min_samples_leaf=16;, score=-0.071 total time=   1.1s
# [CV 5/5] END l2_regularization=1.5576484993327115, learning_rate=0.40124562860940705, max_bins=207, max_iter=770, max_leaf_nodes=13, min_samples_leaf=19;, score=-0.058 total time=   1.6s
# /home/miky/env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
#
#
# 30 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/miky/env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/miky/env/lib/python3.11/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/home/miky/env/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/home/miky/env/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_leaf_nodes' parameter of HistGradientBoostingRegressor must be an int in the range [2, inf) or None. Got 1 instead.
#
#
# /home/miky/env/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1102: UserWarning:
#
# One or more of the test scores are non-finite: [-0.04665763 -0.05198643 -0.05113803 -0.05234496 -0.04864705 -0.05285536
#  -0.0470137  -0.04836036 -0.05654422 -0.05271569 -0.05231192 -0.05708217
#  -0.04974267         nan         nan -0.05398963 -0.06981718 -0.04858346
#  -0.04598673 -0.04741291 -0.05123479 -0.05131481 -0.04707777 -0.04916652
#  -0.04918572 -0.04875297 -0.05707923         nan -0.04891004 -0.05060501
#  -0.05363316 -0.04863232 -0.04828424 -0.05025807 -0.04748644 -0.0494664
#  -0.05407165 -0.05250005 -0.04754813 -0.05051135 -0.05357881 -0.04923655
#  -0.04802381 -0.05217319 -0.05714158 -0.05253458 -0.04825076 -0.04929679
#  -0.05197947         nan -0.05060849 -0.04711251 -0.05974537 -0.05043536
#  -0.05614576 -0.04610199 -0.04731451 -0.05687171 -0.0532655          nan
#  -0.05071541 -0.04965717 -0.05222437 -0.04575074 -0.04835461 -0.05374548
#  -0.04931471 -0.05109866 -0.05154396 -0.05032281 -0.05070005 -0.05055785
#  -0.04954744 -0.04659344 -0.06144669 -0.05122627 -0.05579837 -0.05403019
#  -0.04665317 -0.05037531         nan -0.04914463 -0.05212968 -0.05063989
#  -0.04658483 -0.04983618 -0.04730276 -0.04781619 -0.04667049 -0.04796626
#  -0.04599015 -0.04920968 -0.04963186 -0.04733123 -0.0513511  -0.05923651
#  -0.0502678  -0.04948956 -0.05191409 -0.05525029]
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=HistGradientBoostingRegressor(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'l2_regularization': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7fd91d8925d0>,
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen objec...
#                                         'max_bins': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7fd91d892950>,
#                                         'max_iter': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7fd91f19ca90>,
#                                         'max_leaf_nodes': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7fd91e8c3b50>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7fd91d8922d0>},
#                    scoring='neg_mean_absolute_percentage_error', verbose=3)

# %%
rscv.best_estimator_
# Out:
# HistGradientBoostingRegressor(l2_regularization=1.4300825251801876,
#                               learning_rate=0.07427500203284511, max_bins=122,
#                               max_iter=611, max_leaf_nodes=15,
#                               min_samples_leaf=26)

# %%
y_pred = rscv.predict(X_test)
mean_absolute_error(y_true=y_test,y_pred=y_pred),mean_absolute_percentage_error(y_true=y_test,y_pred=y_pred)
# Out:
# (681.2401395086462, 0.04409279801761577)

# %%
eval_df = test_df[test_df.index<pd.to_datetime("September 1 2020")].copy()
X_eval = eval_df.select_dtypes(exclude=["datetime"]).drop(columns=["Target","Ontario_Demand","Weekday"])
eval_df["preds"] = rscv.predict(X_eval)
eval_df["abs_error"] = (eval_df["Target"] - eval_df["preds"]).abs()
agg_df = eval_df.groupby(eval_df.index.floor("d")).agg({"abs_error":["mean","count"]})
agg_df.columns = ["mean","count"]
agg_df.sort_values(["mean"])
# Out:
#                    mean  count
# DateTime
# 2020-07-21   320.095559     24
# 2020-08-07   365.771352     23
# 2020-07-15   382.773643     24
# 2020-08-06   402.382959     21
# 2020-08-27   431.869870     24
# ...                 ...    ...
# 2020-08-25  1411.654497     24
# 2020-08-09  1434.971870     22
# 2020-08-04  1459.761256     23
# 2020-08-26  1532.602324     24
# 2020-07-26  1904.889073     19
#
# [62 rows x 2 columns]

# %%
joblib.dump(rscv,"model.pickle")
# Out:
# ['model.pickle']
